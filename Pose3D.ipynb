# %% [markdown]
# # Install

# %%
# !git clone https://github.com/zh-plus/video-to-pose3D
# Out:
# Cloning into 'video-to-pose3D'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 1242 (delta 0), reused 2 (delta 0), pack-reused 1237
# Receiving objects: 100% (1242/1242), 11.46 MiB | 10.03 MiB/s, done.
# Resolving deltas: 100% (603/603), done.

# %%
# %cd video-to-pose3D/
# !wget https://dl.fbaipublicfiles.com/video-pose-3d/pretrained_h36m_detectron_coco.bin
# Out:
# --2021-01-10 15:58:51--  https://dl.fbaipublicfiles.com/video-pose-3d/pretrained_h36m_detectron_coco.bin
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 104.22.74.142, 172.67.9.4, 104.22.75.142, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|104.22.74.142|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 67892577 (65M) [application/octet-stream]
# Saving to: ‘pretrained_h36m_detectron_coco.bin’
#
# pretrained_h36m_det 100%[===================>]  64.75M  11.5MB/s    in 6.8s
#
# 2021-01-10 15:58:58 (9.54 MB/s) - ‘pretrained_h36m_detectron_coco.bin’ saved [67892577/67892577]

# %%
# !wget --load-cookies /tmp/cookies.txt "https://drive.google.com/u/0/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://drive.google.com/u/0/uc?export=download&confirm=qwKM&id=1D47msNOOiJKvPOXlnpyzdKA3k6E97NTC' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1D47msNOOiJKvPOXlnpyzdKA3k6E97NTC"
# Out:
# --2021-01-10 15:44:34--  https://drive.google.com/u/0/uc?export=download&confirm=CR3R&id=1D47msNOOiJKvPOXlnpyzdKA3k6E97NTC
# Resolving drive.google.com (drive.google.com)... 108.177.126.139, 108.177.126.138, 108.177.126.102, ...
# Connecting to drive.google.com (drive.google.com)|108.177.126.139|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0g-bk-docs.googleusercontent.com/docs/securesc/5jhfd2mpfrk36uurkmp52ljag7nb2ijm/ae9cd64ikf8rrm7fj6jou3f1tso7391t/1610293425000/00616984542336835036/01095437899742331172Z/1D47msNOOiJKvPOXlnpyzdKA3k6E97NTC?e=download [following]
# --2021-01-10 15:44:35--  https://doc-0g-bk-docs.googleusercontent.com/docs/securesc/5jhfd2mpfrk36uurkmp52ljag7nb2ijm/ae9cd64ikf8rrm7fj6jou3f1tso7391t/1610293425000/00616984542336835036/01095437899742331172Z/1D47msNOOiJKvPOXlnpyzdKA3k6E97NTC?e=download
# ...

# %%
# !wget --load-cookies /tmp/cookies.txt "https://drive.google.com/u/0/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://drive.google.com/u/0/uc?export=download&confirm=D8Ur&id=1OPORTWB2cwd5YTVBX-NE8fsauZJWsrtW' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1OPORTWB2cwd5YTVBX-NE8fsauZJWsrtW"
# Out:
# --2021-01-10 15:48:36--  https://drive.google.com/u/0/uc?export=download&confirm=wj0_&id=1OPORTWB2cwd5YTVBX-NE8fsauZJWsrtW
# Resolving drive.google.com (drive.google.com)... 108.177.126.102, 108.177.126.138, 108.177.126.139, ...
# Connecting to drive.google.com (drive.google.com)|108.177.126.102|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0k-1g-docs.googleusercontent.com/docs/securesc/1hs4akq252504giiocfee9bv4leiscoq/iqm2msjui51kfdovboh5v5810v7r2p2q/1610293650000/00616984542336835036/14449580902339001936Z/1OPORTWB2cwd5YTVBX-NE8fsauZJWsrtW?e=download [following]
# --2021-01-10 15:48:36--  https://doc-0k-1g-docs.googleusercontent.com/docs/securesc/1hs4akq252504giiocfee9bv4leiscoq/iqm2msjui51kfdovboh5v5810v7r2p2q/1610293650000/00616984542336835036/14449580902339001936Z/1OPORTWB2cwd5YTVBX-NE8fsauZJWsrtW?e=download
# ...

# %% [markdown]
# # Test 3D

# %%
# %cd video-to-pose3D/
# !ls
# !python videopose.py
# Out:
# [Errno 2] No such file or directory: 'video-to-pose3D/'
# /content/video-to-pose3D
# asset	     data	       origin_run.py  test
# checkpoint   joints_detectors  outputs	      tools
# checkpoints  lab_processing    pose_trackers  videopose_multi_person.py
# common	     LICENSE	       README.md      videopose.py
# the video is 23.97602432232734 f/s
# Loading YOLO model..
# Loading pose model from joints_detectors/Alphapose/models/sppe/duc_se.pth
# Start pose estimation...
# 100% 4611/4611 [07:49<00:00,  9.82it/s]
# ===========================> Rendering remaining images in the queue...
# ===========================> If this step takes too long, you can enable the --vis_fast flag to use fast rendering (real-time).
# kpts npz save in  outputs/alpha_pose_test/test.npz
# -------------- load data spends 512.68 seconds
# Loading checkpoint checkpoint/pretrained_h36m_detectron_coco.bin
# -------------- load 3D model spends 0.04 seconds
# Rendering...
# ...
